# %% [markdown]
# # Notes: [Topic]
#
# **Date:** [Date]
# **Tags:** #tag1 #tag2 #tag3
#
# ---

# %% [markdown]
# ## Quick Reference
#
# [Quick summary or cheat sheet]

# %% [markdown]
# ## Detailed Notes
#
# ### Section 1
#
# [Your notes]

# %%
# Code snippets

# %% [markdown]
# ## Important Points
#
# - Point 1
# - Point 2
# - Point 3

# %% [markdown]
# ## Related Topics
#
# - [Link to related notebook]
# - [Link to related concept]
